# %% [markdown]
# # library loading

# %%
# 필수 라이브러리 로딩
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import csv
import time
import re # 숫자만 남기려구

# %% [markdown]
# # drive setting

# %%
URL = 'https://www.oliveyoung.co.kr/store/main/main.do?oy=0' # 첫화면
ops = webdriver.ChromeOptions()
ops.add_experimental_option('excludeSwitches', ['enable-logging'])

# chromedriver path
sv = Service(executable_path= 'C:\\Users\\admin\\Downloads\\chroemdriver')
driver = webdriver.Chrome(service=sv, options=ops)

# %% [markdown]
# # 필요 경로 정의 및 요약
# - 페이지 넘기기
# 1. 1페이지 ~ >> 버튼까지
# > for l in range(2,11):<br>
#     driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()<br>
#     ---> 버튼 누른후에도 10개의 리뷰를 읽어옴. (아마)
# 2. 12페이지 부터
# > for l in range(2,12): # 페이지 계산 제대로!! <br>
#     driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()<br>
#     ---> 아마 다음 페이지가 없는경우 오류가 뜰텐데, 해보고 try구문등으로 해결해보기

# %%
# 화면 주소 정의
## 스킨케어
a = 'https://www.oliveyoung.co.kr/store/display/getCategoryShop.do?dispCatNo=10000010001'
## 마스크팩
b = 'https://www.oliveyoung.co.kr/store/display/getCategoryShop.do?dispCatNo=10000010009&gateCd=Drawer'
## 클렌징
c = 'https://www.oliveyoung.co.kr/store/display/getCategoryShop.do?dispCatNo=10000010010&gateCd=Drawer'
## 선케어
d = 'https://www.oliveyoung.co.kr/store/display/getCategoryShop.do?dispCatNo=10000010011&gateCd=Drawer'

# %% [markdown]
# # 한가지 상품의 모든리뷰 가져오기
# ## 상품리뷰페이지 접속

# %%
# 화면 띄우기
## driver.get(url=URL)
## driver = webdriver.Chrome(service=sv, options=ops)
driver.get(url=a)
time.sleep(1)
# 기본페이지 이동
# 스킨케어_토너 페이지로 이동
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)
# 첫번째 제품 선택
driver.find_element(By.XPATH, f'//*[@id="Contents"]/ul[2]/li[{1}]/div/a/img').click()
time.sleep(2)
# 리뷰칸 선택
driver.find_element(By.XPATH, f'//*[@id="reviewInfo"]/a').click()
time.sleep(2)

# %% [markdown]
# ## 한가지 상품의 모든 리뷰 가져오기

# %%
# 1~10번까지의 상품리뷰
for l in range(2,12): # 여기가 바뀜
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
    time.sleep(2)
    for n in range(1,11):
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, rv[0])
        # csv_writer.writerow((pname, rv))
        time.sleep(1)
# Out:
# 1 츈식이
# 2 Ailin
# 3 pipi****
# 4 hhk****
# 5 next****
# 6 qswd
# 7 굼젤
# 8 inho****
# 9 queenka****
# 10 ol름정하기어려워
# 1 세시
# 2 숨징짜
# 3 아지숑숑
# 4 슈비루밥
# 5 기억의향기
# 6 ddochll
# 7 좋으면리뷰씀
# 8 굠돌이
# 9 미아0530
# 10 지미팰런
# 1 융몬
# 2 클린즈
# 3 모먼주
# 4 우꾸렐레레
# 5 EKEK
# 6 무무무뭄무뭄
# 7 클린즈
# 8 져니쨘
# 9 레이디킴
# 10 Beer
# 1 마루로
# 2 미아55
# 3 몽이
# 4 뿌가닮은민애
# 5 hiapple
# 6 asd2****
# 7 gytj****
# 8 bsj****
# 9 보리짱
# 10 신짱
# 1 박기량남편
# 2 minhyeon****
# 3 nh****
# 4 mylovew****
# 5 mand****
# 6 041****
# 7 dbsrud****
# 8 yania****
# 9 올영러버덕
# 10 티탕탕
# 1 루피이이
# 2 핫한상품다써보는언니
# 3 인간미
# 4 귀여운춘식이
# 5 보리맘ㅇ2
# 6 pmy****
# 7 토싀리
# 8 홍쥬
# 9 ahah****
# 10 emki****
# 1 idc****
# 2 tndus****
# 3 promed****
# 4 thddk****
# 5 pippy****
# 6 yujeong****
# 7 담곰맘
# 8 이쭘
# 9 ValCi
# 10 쁘니쁘니이쁘니
# 1 찡짱맨
# 2 nklo****
# 3 엄마까투리
# 4 엄마까투리
# 5 jy0318
# 6 pipi****
# 7 멍뭉아야옹해봐
# 8 민들레미나리달래냉이
# 9 UuUjJj777
# 10 인터밀란
# 1 양하나
# 2 는개
# 3 christ****
# 4 bong05****
# 5 pipi****
# 6 kmjk****
# 7 귤당리
# 8 춘식이하이
# 9 민들레미나리달래냉이
# 10 민쿠민
# 1 멀티비타민
# ...

# %%
# 12 ~ 리뷰가져오기
for l in range(2,12): # 여기가 바뀜
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()
    time.sleep(2)
    for n in range(1,11):
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, rv[0])
        csv_writer.writerow((pname, rv))
        time.sleep(1)
# Out:
# 1 san****
# 2 kja****
# 3 rkdlaos****
# 4 ymjerry****
# 5 kny****
# 6 mszzan****
# 7 wwwlo****
# 8 angelc****
# 9 woghks****
# 10 sj****
# 1 tingri****
# 2 yang****
# 3 jh****
# 4 cryba****
# 5 aaabb
# 6 wjdghl****
# 7 0753a****
# 8 go****
# 9 ensl****
# 10 jml****
# 1 mh14****
# 2 jml****
# 3 sj****
# 4 ss****
# 5 jml****
# 6 tmakdlf****
# 7 moon04****
# 8 thddk****
# 9 gy****
# 10 jhvit****
# 1 hong****
# 2 dpegh****
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/1425977443.py in <module>
#       9         print(n, rv[0])
#      10         # csv_writer.writerow((pname, rstar, keyword,rtext))
# ---> 11         time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# ## csv파일로 내보내기

# %%
# csv파일 만들기
csv_filename = 'rvT1.csv' # 1번시도
csv_open = open(csv_filename, 'w+', encoding = 'utf-8')
csv_writer = csv.writer(csv_open)
csv_writer.writerow(('pname','rv'))

# 닫기
# csv_open.close()
# Out:
# 10

# %%
y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
name = y.split(sep='\n')[0]
name
# Out:
# 'westside****'

# %%
#### test
for l in range(2,12):
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
    time.sleep(2driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
    for n in range(1,11):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        name = y.split(sep='\n')[0]
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, name, rv[0])
        # csv_writer.writerow((pname, rv))
        time.sleep(1)    # 1페이지 누락됨
# Out:
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 5점
# 8 5점만점에 4점
# 9 5점만점에 5점
# 10 5점만점에 5점
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 5점
# 8 5점만점에 4점
# 9 5점만점에 5점
# 10 5점만점에 5점
# 1 5점만점에 5점
# 2 5점만점에 4점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 4점
# 7 5점만점에 3점
# 8 5점만점에 5점
# 9 5점만점에 4점
# 10 5점만점에 5점
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 5점
# 8 5점만점에 5점
# 9 5점만점에 5점
# 10 5점만점에 5점
# 1 5점만점에 4점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 4점
# 8 5점만점에 5점
# 9 5점만점에 4점
# 10 5점만점에 5점
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 4점
# 8 5점만점에 5점
# 9 5점만점에 5점
# 10 5점만점에 5점
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# 7 5점만점에 5점
# 8 5점만점에 5점
# 9 5점만점에 5점
# 10 5점만점에 4점
# 1 5점만점에 5점
# 2 5점만점에 5점
# 3 5점만점에 5점
# 4 5점만점에 5점
# 5 5점만점에 5점
# 6 5점만점에 5점
# ...

# %%
# 11페이지
for l in range(2,12):
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
    time.sleep(2)
    for n in range(1,11):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, rv[0])
        csv_writer.writerow((pname, rv))
        time.sleep(1)    # 1페이지 누락됨
# Out:
# 1 k202212107****
# 2 roc****
# 3 ore****
# 4 js****
# 5 올리브영마스터
# 6 루피이이
# 7 miao
# 8 뚜룬뚜룬
# 9 슈팅린다
# 10 영이영이
# 1 세시
# 2 숨징짜
# 3 아지숑숑
# 4 슈비루밥
# 5 기억의향기
# 6 ddochll
# 7 좋으면리뷰씀
# 8 굠돌이
# 9 미아0530
# 10 지미팰런
# 1 융몬
# 2 클린즈
# 3 모먼주
# 4 우꾸렐레레
# 5 EKEK
# 6 무무무뭄무뭄
# 7 클린즈
# 8 져니쨘
# 9 레이디킴
# 10 Beer
# 1 마루로
# 2 미아55
# 3 몽이
# 4 뿌가닮은민애
# 5 hiapple
# 6 asd2****
# 7 gytj****
# 8 bsj****
# 9 보리짱
# 10 신짱
# 1 박기량남편
# 2 minhyeon****
# 3 nh****
# 4 mylovew****
# 5 mand****
# 6 041****
# 7 dbsrud****
# 8 yania****
# 9 올영러버덕
# 10 티탕탕
# 1 루피이이
# 2 핫한상품다써보는언니
# 3 인간미
# 4 귀여운춘식이
# 5 보리맘ㅇ2
# 6 pmy****
# 7 토싀리
# 8 홍쥬
# 9 ahah****
# 10 emki****
# 1 idc****
# 2 tndus****
# 3 promed****
# 4 thddk****
# 5 pippy****
# 6 yujeong****
# 7 담곰맘
# 8 이쭘
# 9 ValCi
# 10 쁘니쁘니이쁘니
# 1 찡짱맨
# 2 nklo****
# 3 엄마까투리
# 4 엄마까투리
# 5 jy0318
# 6 pipi****
# 7 멍뭉아야옹해봐
# 8 민들레미나리달래냉이
# 9 UuUjJj777
# 10 인터밀란
# 1 양하나
# 2 는개
# 3 christ****
# 4 bong05****
# 5 pipi****
# 6 kmjk****
# 7 귤당리
# 8 춘식이하이
# 9 민들레미나리달래냉이
# 10 민쿠민
# 1 멀티비타민
# ...

# %%
# 12 ~
for l in range(2,12): # 여기가 바뀜
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()
    time.sleep(2)
    for n in range(1,11):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, rv[0])
        csv_writer.writerow((pname, rv))
        time.sleep(1)
# Out:
# 1 san****
# 2 kja****
# 3 rkdlaos****
# 4 ymjerry****
# 5 kny****
# 6 mszzan****
# 7 wwwlo****
# 8 angelc****
# 9 woghks****
# 10 sj****
# 1 tingri****
# 2 yang****
# 3 jh****
# 4 cryba****
# 5 aaabb
# 6 wjdghl****
# 7 0753a****
# 8 go****
# 9 ensl****
# 10 jml****
# 1 mh14****
# 2 jml****
# 3 sj****
# 4 ss****
# 5 jml****
# 6 tmakdlf****
# 7 moon04****
# 8 thddk****
# 9 gy****
# 10 jhvit****
# 1 hong****
# 2 dpegh****
# 3 sophi****
# 4 my1****
# 5 jin****
# 6 anqltmxk****
# 7 fac****
# 8 voyzone****
# 9 voyzone****
# 10 sgh****
# 1 bbyong****
# 2 phs****
# 3 jhlov****
# 4 1130****
# 5 khw****
# 6 ekdms****
# 7 tjtk****
# 8 psyclo****
# 9 phj****
# 10 tjtk****
# 1 cjt****
# 2 yhlee****
# 3 a95****
# 4 mari****
# 5 kj****
# 6 momen****
# 7 mkm****
# 8 fbansg****
# 9 alswl****
# 10 kmpro****
# 1 uniu****
# 2 hwayoung****
# 3 qazx****
# 4 fjqm20****
# 5 haein****
# 6 dkswog****
# 7 gytj****
# 8 kito****
# 9 reallyt****
# 10 hoya****
# 1 blazed****
# 2 qq****
# 3 dldbwls****
# ...

# %%
csv_open.close()

# %%
# 작성자별 옵션이 달라서 다른 방식을
driver.find_element(By.XPATH, '//*[@id="gdasList"]/li[9]/div[2]').text

## 위에서 div[2]추가됨
# Out:
# '5점만점에 5점\n2022.01.01 매장\n피부타입\n복합성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자극없이 순해요\n친오빠가 화장품 고민을 엄청 하고 있길래 우르오스 스킨로션을 테스트성으로 구매해서 보내줬습니다!!\n(두 말할 필요 없이, 한 번 써보고 스스로 느끼라는 의미로 ㅎㅎ) \n\n우선 가격도 저렴한 편이라 꾸준히 사용하기에 부담도 없고, 양도 꽤 많아서 한 번 사면 오래 사용할 수 있더라구요 :)\n\n이 구매를 계기로 우르오스에 정착한 오빠의 후기를 간단히 적어보겠습니다.\n\n향도 좋고, 무엇보다 올인원 제품이라는 점이 매력적으로 다가왔다고 합니다. 세수하고 스킨-에센스-로션 단계별로 바르기 넘 귀찮잖아요 ㅎㅎ 근데 이 모든것을 한 번에 해결할 수 있다는 점이 가장 큰 장점이었고, 건조한 겨울철에 사용해도 덧바르지 않아도 무리 없을 정도의 보습력이 마음에 들었다고 합니다. 아침에 일어났을때도 피부에 윤기가 나고 참 좋다고 하네요 :)\n귀차니즘을 갖고 계신 남자분들께 혁신적인 아이템인 것 같아요!! ㅎㅎ\n이 리뷰가 도움이 돼요! 0\n신고하기'

# %% [markdown]
# # 한가지 상품 버전 2

# %%
# csv파일 만들기
csv_filename = 'rvT2.csv' # 1번시도
csv_open = open(csv_filename, 'w+', encoding = 'utf-8')
csv_writer = csv.writer(csv_open)
csv_writer.writerow(('pname','rv'))

driver.get(url=a)
time.sleep(1)
# 기본페이지 이동
# 스킨케어_토너 페이지로 이동
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)
# 첫번째 제품 선택
driver.find_element(By.XPATH, f'//*[@id="Contents"]/ul[2]/li[{1}]/div/a/img').click()
time.sleep(2)
# 리뷰칸 선택
driver.find_element(By.XPATH, f'//*[@id="reviewInfo"]/a').click()
time.sleep(2)

# 1~11
for l in range(2,12):
    # 페이지 버튼
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
    time.sleep(2)
    for n in range(1,11):
        # 수집정보
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        name = y.split(sep='\n')[0]
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, name)
        csv_writer.writerow((pname, name, rv))
        time.sleep(2)   
        
for l in range(2,12): 
    driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()
    time.sleep(2)
    for n in range(1,11):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        name = y.split(sep='\n')[0]
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(10+n, rv[0])
        csv_writer.writerow((pname, name, rv))
        time.sleep(2)
# Out:
# 1 다다다ㅏㅏ
# 2 버터핑거
# 3 yunsu****
# 4 Beee1
# 5 rbf****
# 6 joylu****
# 7 jinajin****
# 8 ysys****
# 9 noh75****
# 10 okon****
# 1 키키7
# 2 찐바라기
# 3 puris****
# 4 li****
# 5 dtg****
# 6 kkh****
# 7 달빹
# 8 jj****
# 9 k202206086****
# 10 ji12****
# 1 gkwjdal****
# 2 baby****
# 3 Beee1
# 4 flier****
# 5 roal****
# 6 xm****
# 7 xm****
# 8 dldnjsrh****
# 9 sky2****
# 10 sywnj0****
# 1 dmsw****
# 2 kilm****
# 3 sno****
# 4 lim****
# 5 alfo****
# 6 jy****
# 7 ehlee****
# 8 kimyk****
# 9 duddm****
# 10 ehlee****
# 1 mrgo****
# 2 anhope****
# 3 sprite****
# 4 키키7
# 5 1598g****
# 6 sen****
# 7 lcww****
# 8 rainis****
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/1844113218.py in <module>
#      26         # 수집정보
#      27         pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
# ...

# %%
csv_open.close()

# %% [markdown]
# # try구문 추가

# %%
# csv파일 만들기
csv_filename = 'rvT3.csv' # 1번시도
csv_open = open(csv_filename, 'w+', encoding = 'utf-8')
csv_writer = csv.writer(csv_open)
csv_writer.writerow(('pname','rv'))

driver.get(url=a)
time.sleep(1)
# 기본페이지 이동
# 스킨케어_토너 페이지로 이동
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)
# 첫번째 제품 선택
driver.find_element(By.XPATH, f'//*[@id="Contents"]/ul[2]/li[{2}]/div/a/img').click()
time.sleep(2)
# 리뷰칸 선택
driver.find_element(By.XPATH, f'//*[@id="reviewInfo"]/a').click()
time.sleep(2)

try:
    
# 1~11
    for l in range(2,12):
    # 페이지 버튼
        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
        time.sleep(2)
        for n in range(1,11):
        # 수집정보
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
            name = y.split(sep='\n')[0]
            x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
            rv = x.split(sep='\n')
            del rv[-2:]
            print(n, name)
            csv_writer.writerow((pname, name, rv))
            time.sleep(2)   
except:
    pass

try:
    for l in range(2,12): 
        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()
        time.sleep(2)
        for n in range(1,11):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
            name = y.split(sep='\n')[0]
            x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
            rv = x.split(sep='\n')
            del rv[-2:]
            print(10+n, rv[0])
            csv_writer.writerow((pname, name, rv))
            time.sleep(2)
except:
    pass

# %% [markdown]
# # 전체 리뷰 가져오는 고민중
# - 보통 10의 배수 간격으로 for문이 실행됨.
# - 리뷰수를 가지고 for문의 범위를 지정할 순 없을까.
# - str을 list로 변경해서 리스트의 크기로 어느정도 정할수 있지 않을까??
# --> 일의 자리수의 경우 range(1, 일의자리수 +1) 이런식으로 for문 하면 될듯.
# --> 무한 반복은 while문을 활용하면 좋을듯

# %%
driver.find_element(By.XPATH, '//*[@id="reviewInfo"]/a/span').text
# Out:
# '(6,137)'

# %%
q = driver.find_element(By.XPATH, '//*[@id="reviewInfo"]/a/span').text

# %%
int(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/4068363002.py in <module>
# ----> 1 int(q)
#
# ValueError: invalid literal for int() with base 10: '(6,137)'

# %%
q = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[2]/div/div[2]/p[1]/em').text

# %%
int(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/4068363002.py in <module>
# ----> 1 int(q)
#
# ValueError: invalid literal for int() with base 10: '6,137'

# %%
q = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[2]/div/div[2]/p[1]/em').text
q = int(re.sub(r"[^0-9]", "", q))
print(q)
# Out:
# 6137

# %%
q = int(re.sub(r"[^0-9]", "", q))
q
# Out:
# 6137

# %% [markdown]
# <순서>
# - 상품페이지 들어가기
# - 리뷰칸으로 이동
# - 리뷰건수 읽어와서 int화시키기
# - 리뷰수를 기준으로 for문 반복하기

# %%
# 페이지 버튼수
driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[7]').text
# Out:
# '1 2 3 4 5 6'

# %%
# 페이지 내의 리뷰수 
driver.find_element(By.XPATH, '//*[@id="gdasList"]').text
# Out:
# 'ehlee****\n5점만점에 5점\n2022.12.13\n피부타입\n복합성에 좋아요\n피부고민\n진정에 좋아요\n자극도\n보통이에요\n잘받았습니다 감사합니다잘받겠습니다 감사합니다…..\n이 리뷰가 도움이 돼요! 3\n신고하기\nmrgo****\n재구매\n5점만점에 5점\n2022.12.12 매장\n피부타입\n건성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자극없이 순해요\n진짜 세럼 건너 뛰어도 돼요 말만 세럼스킨아니고 진짜 세럼 바른것만큼 촉촉해요 가볍지만 촉촉하게 스킨케어 하고싶은날 이거 하나만 듬뿍 발라보세요\n이 리뷰가 도움이 돼요! 6\n신고하기\nanhope****\n5점만점에 5점\n2022.12.05 매장\n피부타입\n복합성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자극없이 순해요\n남편이 특히 좋아하는데 올영 세일에 가격이 좋아서 아묻따 구입요\n이 리뷰가 도움이 돼요! 6\n신고하기\nsprite****\n5점만점에 5점\n2022.11.28\n피부타입\n복합성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자극없이 순해요\n디파영상보고, 매번 크림과 함께 구매해서 잘쓰고 있어요!!\n디파 세럼스킨\n이 리뷰가 도움이 돼요! 8\n신고하기\n키키7\n5점만점에 4점\n2022.12.13\n피부타입\n복합성에 좋아요\n피부고민\n진정에 좋아요\n자극도\n자극없이 순해요\n특이하게 병에 들어있네요? 병이라 가격이 비싼건가용 \n쎄일\n이 리뷰가 도움이 돼요! 2\n신고하기\n1598g****\n5점만점에 5점\n2022.12.25\n피부타입\n건성에 좋아요\n피부고민\n보습에 좋아요\n자극도\n자극없이 순해요\n유튜브 보고 구매했는데 대박인데요?? 제 피부가 민감해서 괜찮는 제품 구매해도 간지럽거나 뭐가 나는데 이번에 구입한거는 대만족! 민감피부에 추천합니다 너무 좋아요!!!\n이 리뷰가 도움이 돼요! 3\n신고하기\nsen****\n5점만점에 5점\n2022.12.23\n피부타입\n건성에 좋아요\n피부고민\n보습에 좋아요\n자극
# ...

# %%
# elements는 값을 리스트로 반환하기 때문에 수를 세서 개수를 파악할수 있다.
elements = driver.find_elements(By.CSS_SELECTOR,'#gdasList > li')
 
print( '상품 개수: {}'.format( len(elements) ) )
# Out:
# 상품 개수: 9

# %%
rr = driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a')
#gdasContentsArea > div > div.pageing
len(rr)
# >>버튼 까지(다음버튼이 없으면 해당 페이지가 마지막임)
# Out:
# 11

# %% [markdown]
# - tag확인으로 range범위 생성
# - 무한 반복 후 tag에 >>이 없으면 데이터 수집후 break
# --> 리뷰가 10개 미만인 경우 함수정의
# --> 리뷰가 10개 이상인 경우 함수정의

# %%
# 10개 이하인 경우 리뷰 수를 세서 크롤링
# 사전에 리뷰수(n_rv)를 읽어와야함
def little(n_rv):
    for i in range(1, n_rv+1):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
        name = y.split(sep='\n')[0]
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        print(n, name)
        csv_writer.writerow((pname, name, rv))
        time.sleep(2)

# 10개 이상인 경우 버튼수 체크후 크롤링
# 사전에 버튼수(n_bt)를 읽어와야함. 
def large(n_bt):
    if n_bt == 11:
        for l in range(2,12): # 1~11
    # 페이지 버튼
            driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
            time.sleep(2)
            n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
            for n in range(1,n_rv+1): # 리뷰수
            # 수집정보
                pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
                y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
                name = y.split(sep='\n')[0]
                x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
                rv = x.split(sep='\n')
                del rv[-2:]
                print(n, name)
                csv_writer.writerow((pname, name, rv))
                time.sleep(2)
                
        for l in range(2,12):  # 12~~
            driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l}]').click()
            time.sleep(2)
            n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
            for n in range(1,1n_rv+1):
                pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
                y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
                name = y.split(sep='\n')[0]
                x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
                rv = x.split(sep='\n')
                del rv[-2:]
                print(10+n, rv[0])
                csv_writer.writerow((pname, name, rv))
                time.sleep(2)
    else:
        for l in range(2,n_bt+1):
            driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
            time.sleep(2)
            n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
            for n in range(1,n_rv+1): # 리뷰수
            # 수집정보
                pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
                y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]').text
                name = y.split(sep='\n')[0]
                x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{n}]/div[2]').text
                rv = x.split(sep='\n')
                del rv[-2:]
                print(n, name)
                csv_writer.writerow((pname, name, rv))
                time.sleep(2)
            
        
    n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
    
    # >> 버튼이 존재하면 1, 아니면 0
    next_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a.next'))

# %%
if >>tag in elements:
    # 데이터 끌어오고
    
else: # >>버튼이 없음
    # 데이터 가져오고
    break

# %%
for i in range(1, len(rr)+1):

# %% [markdown]
# ## while 구문 사용하여 리뷰 가져기
# ### 가능한지 확인

# %%
# 페이지 넘어가는 부분 확인
n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))

while n_bt == 11: 
    # 12~~ //*[@id="gdasContentsArea"]/div/div[8]/strong
    # //*[@id="gdasContentsArea"]/div/div[8]/a[2]
    for l in range(2, n_bt+1):

        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[8]/a[{l}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(2, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
            print(l, pname)
# Out:
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# ...

# %%
for l in range(2, n_bt+1):

        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[8]/a[{l}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(2, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
            print(l, pname)
# Out:
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 2 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# 3 [대용량+미니어처] 넘버즈인 3번 결광가득 에센스 토너 300ml 어워즈 한정기획 (+3번 결광케어 키트 5종 증정)
# ...

# %% [markdown]
# ## 사용자 정의 함수

# %%
# while문 함수정의
def rv_while(next_bt, n_bt, q):
    while next_bt == 1: 
    # 12~~ //*[@id="gdasContentsArea"]/div/div[8]/strong
    # #gdasContentsArea > div > div.pageing > strong
    # //*[@id="gdasContentsArea"]/div/div[8]/a[2]
        for l in range(2, n_bt+2):
            driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[{q}]/a[{l}]').click()
            time.sleep(2)
            n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
            for i in range(1, n_rv+1):
                pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
                y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]').text
                name = y.split(sep='\n')[0]
                x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]/div[2]').text
                rv = x.split(sep='\n')
                del rv[-2:]
                csv_writer.writerow((pname, name, rv))
                time.sleep(2)
                print(i, pname)
        
            n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
        
        next_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a.next'))
                
    for l in range(2, n_bt+2):

        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[{q}]/a[{l}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(1, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]').text
            name = y.split(sep='\n')[0]
            x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]/div[2]').text
            rv = x.split(sep='\n')
            del rv[-2:]
            csv_writer.writerow((pname, name, rv))
            time.sleep(2)
            print(i, pname)
        n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))

# %%
len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a.next'))
#gdasContentsArea > div > div.pageing
#gdasContentsArea > div > div.pageing > a.next
# Out:
# 0

# %%
# 1페이지 정보 긁어오는 함수
def rv_first():
    n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
    for i in range(1, n_rv+1):
        pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
        y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]').text
        name = y.split(sep='\n')[0]
        x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]/div[2]').text
        rv = x.split(sep='\n')
        del rv[-2:]
        csv_writer.writerow((pname, name, rv))
        time.sleep(2)
        # n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a')) 중복
        print(i, pname)

# %%
# 페이지수가 10개 이하인경우 긁어오는 함수
def rv_else(n_bt):
    print(n_bt)
    for l in range(2, n_bt+2):
        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(1, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]').text
            name = y.split(sep='\n')[0]
            x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]/div[2]').text
            rv = x.split(sep='\n')
            del rv[-2:]
            csv_writer.writerow((pname, name, rv))
            time.sleep(2)
            print(i, pname)
        n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))

# %%
# 48개씩 보는 경로 설정
## //*[@id="Contents"]/div[5]/div[2]/ul/li[3]/a
# 상품 페이지 넘기는 경로 설정
## //*[@id="Container"]/div[2]/a[1] # 2페이지
## //*[@id="Container"]/div[2]/a[2] 3페이지

# %%
# //*[@id="gdasContentsArea"]/div/div[1]/div/div[2]/p[1]/em
c = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[1]/div/div[2]/p[1]/em').text
c = int(re.sub(r"[^0-9]", "", c))
q = [8 if c >= 1000 else 7][0]
print(q)
# Out:
# 8

# %%
# 첫페이지 상품들 수집
def f_choice(cate):
    ## 카테고리 선택 부분(중)
    driver.get(url= cate)
    time.sleep(2)
    ## 상품 개수 설정 (48개씩 보기)
    driver.find_element(By.XPATH, '//*[@id="Contents"]/div[5]/div[2]/ul/li[3]/a').click()
    for i in range(1, 13):
        for j in range(1,5):
    ## 상품 선택
            driver.find_element(By.XPATH,f'//*[@id="Contents"]/ul[{i+1}]/li[{j}]/div/a/img').click()
            time.sleep(2)
            driver.find_element(By.XPATH,f'//*[@id="reviewInfo"]/a').click() # 리뷰칸 이동
            time.sleep(2)
            # 리뷰 갯수 path 변수 설정
            c = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[2]/div/div[2]/p[1]/em').text
            c = int(re.sub(r"[^0-9]", "", q))
            q = ''.join([8 if q >= 1000 else 7])
                
            rv_first(q)
            n_bt = len(driver.find_elements(By.CSS_SELECTOR, '#gdasContentsArea > div > div.pageing > a'))
                # >> 버튼이 존재하면 1, 아니면 0
            next_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a.next'))
            if next_bt == 1:
                rv_while(n_bt,q)
            else:
                rv_else(n_bt)
            driver.back()

# %%
# 제품 선택 함수 
## 상품 페이지 2번 클릭후 진행되는거임...
def p_choice():
    # driver.find_element(By.XPATH, '//*[@id="Contents"]/div[5]/div[2]/ul/li[3]/a').click() #cate 중복이라 제거
    # time.sleep(2)
    for k in range(1, 11):
        # 상품들의 페이지수 넘기는거(11페이지까지 읽어올듯)
        driver.find_element(By.XPATH, f'//*[@id="Container"]/div[2]/a[{k}]').click()
        time.sleep(2)
        for i in range(1, 13):
            for j in range(1,5):
                # 상품 선택
                driver.find_element(By.XPATH,f'//*[@id="Contents"]/ul[{i+1}]/li[{j}]/div/a/img').click()
                time.sleep(2)
                driver.find_element(By.XPATH,f'//*[@id="reviewInfo"]/a').click() # 리뷰칸 이동
                time.sleep(2)
                # 리뷰 갯수 path 변수 설정
                q = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[2]/div/div[2]/p[1]/em').text
                q = int(re.sub(r"[^0-9]", "", q))
                
                rv_first(q)
                n_bt = len(driver.find_elements(By.CSS_SELECTOR, '#gdasContentsArea > div > div.pageing > a'))
                # >> 버튼이 존재하면 1, 아니면 0
                next_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a.next'))
                if next_bt == 1:
                    rv_while(n_bt,q)
                else:
                    rv_else(n_bt)
                driver.back()

# %%
# 함수 적용해보기
## 리뷰 59개인 제품

n_bt = len(driver.find_elements(By.CSS_SELECTOR, '#gdasContentsArea > div > div.pageing > a'))
if n_bt == 11:
    rv_while(n_bt)
else:
    print(n_bt)
    for l in range(2, n_bt+2):
        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[7]/a[{l-1}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(1, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            y = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]').text
            name = y.split(sep='\n')[0]
            x = driver.find_element(By.XPATH, f'//*[@id="gdasList"]/li[{i}]/div[2]').text
            rv = x.split(sep='\n')
            del rv[-2:]
            csv_writer.writerow((pname, name, rv))
            time.sleep(2)
            n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
            print(i, pname)
# Out:
# 5
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# ...

# %% [markdown]
# ### 실제 가져와 보기1

# %%
### writer 속성 키고 실행함
# csv생성
csv_filename = 'rvT4.csv' # 사용자 함수 사용해서 긁어오기 1번 시도
csv_open = open(csv_filename, 'w+', encoding = 'utf-8')
csv_writer = csv.writer(csv_open)
csv_writer.writerow(('pname', 'name','rv'))
driver.get(url=a)
time.sleep(1)

# 기본페이지 이동
# 스킨케어_토너 페이지로 이동
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)

# 상품 선택 및 for문
p_choice()
# 파일 닫기
csv_open.close()
# Out:
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 5
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# ...

# %%
csv_open.close()

# %% [markdown]
# - rvT4 = 인터미션 레스트 업 세럼 스킨 200ml 리뷰들

# %% [markdown]
# ### data화 하기

# %%
driver.get(url=a)
time.sleep(1)
# 기본페이지 이동
# 스킨케어_토너 페이지로 이동
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)
# 1_2번쨰 제품 선택
driver.find_element(By.XPATH, f'//*[@id="Contents"]/ul[2]/li[{2}]/div/a/img').click()
time.sleep(2)
# 리뷰칸 선택
driver.find_element(By.XPATH, f'//*[@id="reviewInfo"]/a').click()
time.sleep(2)

n_bt = len(driver.find_elements(By.CSS_SELECTOR, '#gdasContentsArea > div > div.pageing > a'))
if n_bt = 11:
    rv_while(n_bt)
else:
    for l in range(2, n_bt+1):
        driver.find_element(By.XPATH, f'//*[@id="gdasContentsArea"]/div/div[8]/a[{l}]').click()
        time.sleep(2)
        n_rv = len(driver.find_elements(By.CSS_SELECTOR,'#gdasList > li'))
        for i in range(2, n_rv+1):
            pname = driver.find_element(By.XPATH,'//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text
            n_bt = len(driver.find_elements(By.CSS_SELECTOR,'#gdasContentsArea > div > div.pageing > a'))
            print(l, pname)

# %%
csv_open.close()

# %%
for i in range(1, 7):
    for j in range(1,5):
        driver.find_element(By.XPATH,f'//*[@id="Contents"]/ul[{i+1}]/li[{j}]/div/a/img').click()
        driver.find_element(By.XPATH,f'//*[@id="reviewInfo"]/a').click()
        time.sleep(2)
        driver.back()

# %%
### 토너 첫페이지 상품별 리뷰가져오기

# csv생성
csv_filename = 'rvT5.csv' # 사용자 함수 사용해서 긁어오기 2번 시도
csv_open = open(csv_filename, 'w+', encoding = 'utf-8')
csv_writer = csv.writer(csv_open)
csv_writer.writerow(('pname', 'name','rv'))
driver.get(url=a)  # 기초화장품 페이지 접근
time.sleep(1)

# 스킨케어_토너 페이지로 이동
## 나중에 이걸로 페이지 조정하면 될듯
driver.find_element(By.XPATH, f'//*[@id="Contents"]/div/div[1]/ul/li[1]/a').click()
time.sleep(2)

# 상품 선택 및 for문
p_choice()

# 파일 닫기
csv_open.close()
# Out:
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 5
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# 7 인터미션 레스트 업 세럼 스킨 200ml
# 8 인터미션 레스트 업 세럼 스킨 200ml
# 9 인터미션 레스트 업 세럼 스킨 200ml
# 10 인터미션 레스트 업 세럼 스킨 200ml
# 1 인터미션 레스트 업 세럼 스킨 200ml
# 2 인터미션 레스트 업 세럼 스킨 200ml
# 3 인터미션 레스트 업 세럼 스킨 200ml
# 4 인터미션 레스트 업 세럼 스킨 200ml
# 5 인터미션 레스트 업 세럼 스킨 200ml
# 6 인터미션 레스트 업 세럼 스킨 200ml
# ...

# %%
csv_open.close()

# %%
q = driver.find_element(By.XPATH, '//*[@id="gdasContentsArea"]/div/div[2]/div/div[2]/p[1]/em').text
q = int(re.sub(r"[^0-9]", "", q))
print(q) # 상품수 
## 리뷰칸으로 이동 후 상품수 체크하고 if로 변수를 설정해 줘야해.
# Out:
# 5236

# %%
# 여기서 특징 천개 이상이면 div[8], 이하면 div[7]
# (1,1) 상품의 페이지 path //*[@id="gdasContentsArea"]/div/div[7]/a[1]
# (1,2) 상품의 페이지 path //*[@id="gdasContentsArea"]/div/div[8]/a[1] # 2번 칸 
# (1,4) //*[@id="gdasContentsArea"]/div/div[8]/a[1] 
# (2,2) //*[@id="gdasContentsArea"]/div/div[7]/a[1]
# (1,1) - 순위따라 계속 바귐. //*[@id="gdasContentsArea"]/div/div[7]/a[1]
